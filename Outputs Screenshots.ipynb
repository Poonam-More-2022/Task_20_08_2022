# %% [markdown]
# # Output Screenshots for SQL queries via API

# %% [markdown]
# ### After Insert command

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### After update query in sql via API

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### After DELETE query in sql via API

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Output Screenshots for MongoDB queries via API

# %% [markdown]
# ### Before Insert command in MongodB
#
# There are total documents are 12 in Table1 of Inventory database before insert

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Executing insert query through API

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Though there was error in displaying records in Postman, the record is successfully inserted in MongodB database via API as you can see in screenshot given below, However this error is later on overcome by using jsonify command but can't able to display records in Postman

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Before Update Query

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### After update query

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Before delete query via api
#
# Here we have two entries of **item:"Pencils"**, and **total documents: 13** before execution of delete query via api

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### After delete query via api
#
# One of the entry for **item : "Pencils"** has been successfully deleted and now **total documents:12** as you can see in screenshot given below

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
